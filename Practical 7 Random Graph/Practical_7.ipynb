# %%
import networkx as nx
import matplotlib.pyplot as plt
import random

# %%
#Creation of giant components
#Taking nodes and probability input from the user
print('Enter number of nodes: ')
n = int(input())
print('Enter value for d: ')
d = float(input())
p = d/n
print("Probability: ",p)
# Out:
# Enter number of nodes:
#  25
# Enter value for d:
#  3
# Probability:  0.12

# %%
#Creating a graph and adding nodes
g = nx.Graph()
g.add_nodes_from(range(1, n+1))

for i in g.nodes():
  for j in g.nodes():
    if i<j:
      r = random.random()
      if r<p:
        g.add_edge(i, j)
pos = nx.circular_layout(g)
nx.draw(g, pos, with_labels = 1, node_size=200,font_size=14)
plt.figure(figsize = (6,4))
plt.show()

# %%
#Taking nodes and probability input from the user
#Creating random graph to check for cycle
print('Enter number of nodes: ')
n = int(input())
print('Enter value for d: ')
d = float(input())
p = d/n
# Out:
# Enter number of nodes:
#  25
# Enter value for d:
#  3

# %%
#Creating a graph and adding nodes
g = nx.Graph()
g.add_nodes_from(range(1, n+1))

for i in g.nodes():
  for j in g.nodes():
    if i<j:
      r = random.random()
      if r<p:
        g.add_edge(i, j)
pos = nx.circular_layout(g)
nx.draw(g, pos, with_labels = 1, node_size=200,font_size=14)
plt.figure(figsize = (6,4))
plt.show()

# %%
#Disappearance of isolated components
#Taking nodes input from the user
import math
print('Enter number of nodes: ')
n = int(input())
p = (math.log(n) / n)
print('Probability : ', p)
# Out:
# Enter number of nodes:
#  25
# Probability :  0.128755032994728

# %%
#Creating a graph and adding nodes
g = nx.Graph()
g.add_nodes_from(range(1, n+1))

for i in g.nodes():
  for j in g.nodes():
    if i<j:
      r = random.random()
      if r<p:
        g.add_edge(i, j)
pos = nx.circular_layout(g)
nx.draw(g, pos, with_labels = 1, node_size=200,font_size=14, font_color = 'white')
plt.figure(figsize = (6,4))
plt.show()
